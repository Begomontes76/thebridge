# %% [markdown]
# ## Mis Primeros pasos con Markdown

# %% [markdown]
# # Cabecera 1
# ## Cabecera 2

# %% [markdown]
# ### Cabcera 3
# #### Cabecera 4
# ##### Cabecera 5
# ###### Cabcera 6
# ####### Cabecera 7

# %% [markdown]
# <h1>Header 1</h1>
# <h2>Header 2</h2>
# <h3>Header 3</h3>

# %% [markdown]
# **Texto en negrita**
#
# *Texto en cursiva*
#
# ***Texto en negrita y en cursivo***

# %% [markdown]
# >Recuerda la importancia del conocimiento de negocio y del dominio
# >>y utilizar atajos de teclado
